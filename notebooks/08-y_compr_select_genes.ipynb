# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

# %%
dir_in = '../out/20.0909 Lx/L200only_reg_rf_boruta_all/'
df_res = pd.read_csv('%s/model_results.csv' % dir_in)

# %%
df_res.loc[(df_res.model == 'top10feat') & (df_res.score_test <0 ), :].sort_values(by='score_test', ascending=True).head(10)
# Out:
#             model    feature   target  score_train  score_test  score_oob  \
# 158736  top10feat  top10feat   SLC8A3     0.402449   -0.387412   0.054108
# 191055  top10feat  top10feat    LUC7L     0.349539   -0.367910   0.049290
# 193796  top10feat  top10feat     CIPC     0.430339   -0.363609   0.034035
# 128907  top10feat  top10feat    KCNQ3     0.381695   -0.356689   0.067168
# 45385   top10feat  top10feat   PTGER2     0.295944   -0.356332   0.026504
# 212169  top10feat  top10feat  FOXL2NB     0.394856   -0.349167   0.118357
# 88760   top10feat  top10feat  NFKBIL1     0.380538   -0.346867   0.039361
# 37947   top10feat  top10feat     RHOJ     0.353035   -0.343675   0.046553
# 32529   top10feat  top10feat      GCG     0.311627   -0.340191   0.030245
# 26770   top10feat  top10feat    GPR78     0.415986   -0.338502   0.081571
#
#         corr_test  corr_test_recall  score_p19q4  corr_p19q4  \
# 158736   0.007327             0.491     0.046443    0.102028
# 191055  -0.051050             0.363    -0.163794   -0.008558
# 193796  -0.013578             0.436    -0.218150   -0.227119
# 128907  -0.068838             0.312    -0.054202    0.013004
# 45385   -0.082051             0.222    -0.064077   -0.071798
# 212169  -0.093114             0.203    -0.115209   -0.072520
# 88760   -0.202741             0.039    -0.129689   -0.101806
# 37947   -0.041864             0.344     0.011098   -0.022117
# 32529   -0.130331             0.118    -0.069421    0.017116
# 26770   -0.333783             0.006    -0.075280   -0.004835
#
#         corr_p19q4_recall  feat_id  feat_idx
# 158736              0.802      NaN       NaN
# 191055              0.481      NaN       NaN
# 193796              0.055      NaN       NaN
# 128907              0.510      NaN       NaN
# 45385               0.321      NaN       NaN
# 212169              0.291      NaN       NaN
# 88760               0.222      NaN       NaN
# 37947               0.395      NaN       NaN
# 32529               0.559      NaN       NaN
# 26770               0.491      NaN       NaN

# %%
df_res.loc[df_res.model == 'top10feat', :].sort_values(by='score_test', ascending=True).tail(10)
# Out:
#             model    feature    target  score_train  score_test  score_oob  \
# 58811   top10feat  top10feat    NDUFA2     0.724785    0.582687   0.517959
# 55224   top10feat  top10feat    NDUFS5     0.792353    0.583249   0.626940
# 92575   top10feat  top10feat    NDUFB8     0.773824    0.597274   0.579511
# 162152  top10feat  top10feat     HARS2     0.721374    0.623211   0.510724
# 139106  top10feat  top10feat     EARS2     0.769919    0.633869   0.587646
# 181437  top10feat  top10feat    MRPL21     0.751267    0.640788   0.547542
# 96840   top10feat  top10feat    NDUFB9     0.764348    0.641033   0.577058
# 50811   top10feat  top10feat  HSD17B10     0.745519    0.647972   0.541697
# 137040  top10feat  top10feat    MRPS24     0.736174    0.655277   0.518884
# 171288  top10feat  top10feat   NDUFB10     0.788743    0.666754   0.605614
#
#         corr_test  corr_test_recall  score_p19q4  corr_p19q4  \
# 58811    0.765036             1.000     0.605377    0.791720
# 55224    0.724976             0.999     0.593762    0.811837
# 92575    0.756470             1.000     0.593136    0.805835
# 162152   0.818619             1.000     0.459758    0.730258
# 139106   0.782496             1.000     0.478282    0.671575
# 181437   0.808686             1.000     0.690162    0.830897
# 96840    0.716538             1.000     0.519249    0.742706
# 50811    0.790406             1.000     0.407812    0.613393
# 137040   0.821080             1.000     0.409720    0.766602
# 171288   0.806973             1.000     0.685638    0.842234
#
#         corr_p19q4_recall  feat_id  feat_idx
# 58811               0.999      NaN       NaN
# 55224               1.000      NaN       NaN
# 92575               1.000      NaN       NaN
# 162152              1.000      NaN       NaN
# 139106              0.997      NaN       NaN
# 181437              1.000      NaN       NaN
# 96840               1.000      NaN       NaN
# 50811               0.997      NaN       NaN
# 137040              0.999      NaN       NaN
# 171288              1.000      NaN       NaN

# %%
res = pickle.load(open('%s/model_perf/y_compr_TP53BP1.pkl' % dir_in,'rb'))
df = res['te']
plt.plot([-2.5,1], [-2.5,1], ls="--", c=".3", alpha=0.5)
ax = sns.scatterplot(df.y_actual, df.y_pred)
ax.set(xlabel='actual', ylabel='predicted', xlim=[-2.5,1], ylim=[-2.5,1])
# Out:
# [Text(0.5, 0, 'actual'), Text(0, 0.5, 'predicted'), (-2.5, 1.0), (-2.5, 1.0)]

# %%
res = pickle.load(open('%s/model_perf/y_compr_XRCC6.pkl' % dir_in,'rb'))
df = res['te']
plt.plot([-2.5,1], [-2.5,1], ls="--", c=".3", alpha=0.5)
ax = sns.scatterplot(df.y_actual, df.y_pred)
ax.set(xlabel='actual', ylabel='predicted', xlim=[-2.5,1], ylim=[-2.5,1])
# Out:
# [(-2.5, 1), Text(0,0.5,'predicted'), (-2.5, 1), Text(0.5,0,'actual')]
