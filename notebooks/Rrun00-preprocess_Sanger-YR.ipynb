# %%
import sys
sys.path.append('../src')

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of ceres_infer.data_addsanger failed: Traceback (most recent call last):
#   File "/Users/stella/miniconda3/envs/cnp/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/stella/miniconda3/envs/cnp/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/stella/miniconda3/envs/cnp/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/stella/miniconda3/envs/cnp/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
# ...

# %%
from ceres_infer.data_addsanger import preprocessDataSanger
preprocessDataSanger(useGene_dependency = False,
                   dir_out = '../out/20.0817 proc_data/gene_effect/',
                   dir_sanger = '../data/DepMap/')
# Out:
# loading Sanger gene effect...
# processing Sanger CERES...
# filtering: baseline feature pruning...

# %%
import pickle
df = pickle.load(open('../out/20.0817 proc_data/gene_effect/dm_data_Sanger.kpl','rb'))
df.df_crispr
# Out:
#             A1BG (1) [CERES]  A1CF (29974) [CERES]  A2M (2) [CERES]  \
# DepMap_ID
# ACH-000005         -0.068759              0.218792         0.178252
# ACH-000007          0.053893              0.081444        -0.060170
# ACH-000009          0.059874             -0.011153        -0.054367
# ACH-000011          0.277165              0.085354         0.007972
# ACH-000012          0.008073              0.167177         0.088705
# ...                      ...                   ...              ...
# ACH-001745          0.208843              0.153637        -0.134906
# ACH-001750          0.044674              0.126563        -0.082100
# ACH-001765          0.136364              0.021261        -0.107147
# ACH-001814          0.216507             -0.172366        -0.265359
# ACH-001838         -0.086149              0.082798        -0.147978
#
#             A2ML1 (144568) [CERES]  A3GALT2 (127550) [CERES]  \
# DepMap_ID
# ACH-000005                0.158390                 -0.193862
# ...

# %%
from ceres_infer.data import preprocessDataQ3Q4
preprocessDataQ3Q4(useGene_dependency = False,
                   dir_out = '../out/20.0817 proc_data/gene_effect/',
                   dir_depmap = '../data/DepMap/')
# Out:
# loading rna-seq...
# loading copy number...
# loading mutations...
# /Users/stella/miniconda3/envs/cnp/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3417: DtypeWarning: Columns (3,19,25,26,27,28,29,30,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# loading sample_info...
# loading Achilles gene effect...
# processing CERES...
# There are 43 cell lines out of 625 that will be dropped, due to missing data
# processing rna-seq...
# processing copy number...
# processing mutations...
# processing sample_info...
# finalizing processing...
# filtering: keep only shared samples...
# filtering: baseline feature pruning...
# loading rna-seq...
# loading copy number...
# loading mutations...
# ...

# %%
# Preprocess data for gene dependency (categorical)
from ceres_infer.data import preprocessDataQ3Q4
preprocessDataQ3Q4(useGene_dependency = True,
                   dir_out = '../out/20.0817 proc_data/gene_dependency/',
                   dir_depmap = '../data/DepMap/')
# Out:
# loading rna-seq...
# loading copy number...
# loading mutations...
# /Users/stella/miniconda3/envs/cnp/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3417: DtypeWarning: Columns (3,19,25,26,27,28,29,30,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# loading sample_info...
# loading Achilles gene dependency...
# processing CERES...
# There are 43 cell lines out of 625 that will be dropped, due to missing data
# processing rna-seq...
# processing copy number...
# processing mutations...
# processing sample_info...
# finalizing processing...
# filtering: keep only shared samples...
# filtering: baseline feature pruning...
# loading rna-seq...
# loading copy number...
# loading mutations...
# ...
