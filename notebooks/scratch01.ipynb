# %% [markdown]
# Getting processed genomic/ceres datasets

# %%
import pickle
import sys
sys.path.append('../')

# %%
dm_data = pickle.load(open('../out/20.0216 feat/reg_rf_boruta/dm_data.pkl','rb'))

# %%
# dm_data.df_crispr
# dm_data.df_rnaseq
# dm_data.df_cn
# dm_data.df_mut
# dm_data.df_lineage
# Out:
#             A1BG (1) [CERES]  A1CF (29974) [CERES]  A2M (2) [CERES]  \
# DepMap_ID
# ACH-000005         -0.068759              0.218792         0.178252
# ACH-000007          0.053893              0.081444        -0.060170
# ACH-000009          0.059874             -0.011153        -0.054367
# ACH-000011          0.277165              0.085354         0.007972
# ACH-000012          0.008073              0.167177         0.088705
# ...                      ...                   ...              ...
# ACH-001745          0.208843              0.153637        -0.134906
# ACH-001750          0.044674              0.126563        -0.082100
# ACH-001765          0.136364              0.021261        -0.107147
# ACH-001814          0.216507             -0.172366        -0.265359
# ACH-001838         -0.086149              0.082798        -0.147978
#
#             A2ML1 (144568) [CERES]  A3GALT2 (127550) [CERES]  \
# DepMap_ID
# ACH-000005                0.158390                 -0.193862
# ACH-000007                0.153435                  0.087362
# ACH-000009                0.060886                  0.039767
# ACH-000011                0.445843                 -0.036717
# ACH-000012                0.307599                  0.015440
# ...                            ...                       ...
# ACH-001745                0.167583                 -0.130067
# ACH-001750                0.132673                 -0.172350
# ACH-001765                0.076223                 -0.116583
# ACH-001814                0.045942                  0.123916
# ACH-001838                0.256595                 -0.054596
#
#             A4GALT (53947) [CERES]  A4GNT (51146) [CERES]  \
# DepMap_ID
# ACH-000005               -0.324566               0.246220
# ACH-000007                0.150684               0.061146
# ACH-000009                0.043527               0.011845
# ACH-000011               -0.261409               0.111173
# ACH-000012               -0.137284               0.264126
# ...                            ...                    ...
# ACH-001745               -0.082006               0.108194
# ACH-001750               -0.294151               0.113662
# ACH-001765                0.071279              -0.007449
# ACH-001814                0.087353              -0.182381
# ACH-001838               -0.280780               0.272638
#
#             AAAS (8086) [CERES]  AACS (65985) [CERES]  AADAC (13) [CERES]  \
# DepMap_ID
# ACH-000005            -0.576495             -0.081217            0.016182
# ACH-000007            -0.470462             -0.012210            0.277616
# ACH-000009            -0.630290              0.161797            0.033587
# ACH-000011            -0.430867              0.138193            0.120785
# ACH-000012            -0.491951              0.073552            0.308495
# ...                         ...                   ...                 ...
# ACH-001745            -0.511436              0.096255            0.091139
# ACH-001750            -0.673395              0.049989           -0.065654
# ACH-001765            -0.458998             -0.069348            0.156374
# ACH-001814            -0.489776              0.005241            0.111024
# ACH-001838            -0.539307              0.156023            0.303969
#
#             ...  ZWILCH (55055) [CERES]  ZWINT (11130) [CERES]  \
# DepMap_ID   ...
# ACH-000005  ...               -0.176432              -0.391199
# ACH-000007  ...               -0.101852              -0.276755
# ACH-000009  ...               -0.355880              -0.290047
# ACH-000011  ...               -0.418769              -0.518908
# ACH-000012  ...               -0.393597              -0.834722
# ...         ...                     ...                    ...
# ACH-001745  ...               -0.006292              -0.598863
# ACH-001750  ...               -0.119853              -0.554706
# ACH-001765  ...               -0.159882              -0.440949
# ACH-001814  ...               -0.128753              -0.243608
# ACH-001838  ...               -0.037258              -0.909466
#
#             ZXDA (7789) [CERES]  ZXDB (158586) [CERES]  ZXDC (79364) [CERES]  \
# DepMap_ID
# ACH-000005            -0.182117              -0.108978              0.186545
# ACH-000007            -0.030821               0.121126              0.214875
# ACH-000009            -0.031825               0.115886              0.116784
# ACH-000011            -0.128187              -0.126336              0.269698
# ACH-000012             0.062316              -0.045060              0.133700
# ...                         ...                    ...                   ...
# ACH-001745             0.191322               0.145424              0.056416
# ACH-001750            -0.161670              -0.046699              0.111985
# ACH-001765             0.001038              -0.065006              0.053587
# ACH-001814            -0.017122               0.271896             -0.081350
# ACH-001838             0.062382              -0.029306             -0.009921
#
#             ZYG11A (440590) [CERES]  ZYG11B (79699) [CERES]  \
# DepMap_ID
# ACH-000005                -0.075884               -0.095781
# ACH-000007                -0.019300               -0.342632
# ACH-000009                 0.035294               -0.575523
# ACH-000011                 0.148516               -0.227106
# ACH-000012                 0.122965               -0.132978
# ...                             ...                     ...
# ACH-001745                 0.125346               -0.089675
# ACH-001750                -0.007653               -0.087820
# ACH-001765                 0.206996               -0.247742
# ACH-001814                 0.281161               -0.088890
# ACH-001838                 0.107554               -0.249966
#
#             ZYX (7791) [CERES]  ZZEF1 (23140) [CERES]  ZZZ3 (26009) [CERES]
# DepMap_ID
# ACH-000005            0.029269               0.000945             -0.242038
# ACH-000007            0.083610              -0.392722             -0.443380
# ACH-000009            0.228940              -0.114559             -0.549906
# ACH-000011            0.120656              -0.252444             -0.401821
# ACH-000012            0.050321              -0.175689             -0.402526
# ...                        ...                    ...                   ...
# ACH-001745            0.063647               0.123191             -0.459169
# ACH-001750            0.009488              -0.302427             -0.259728
# ACH-001765            0.234458              -0.228322             -0.247546
# ACH-001814           -0.040170              -0.377166             -0.395694
# ACH-001838            0.197032              -0.134838             -0.466560
#
# [575 rows x 18333 columns]

# %% [markdown]
# Getting primary model results (reg_rf_boruta)

# %%
import pandas as pd

# %%
# model results
df_res = pd.read_csv('../out/20.0216 feat/reg_rf_boruta/model_results.csv') 

# feature summary, derived from model results (each row unique for feature-target pair)
df_feat = pd.read_csv('../out/20.0216 feat/reg_rf_boruta/anlyz_filtered/feat_summary.csv')

# feature summary additional metrics, derived from model results (each row unique for feature-target pair)
df_feat2 = pd.read_csv('../out/20.0216 feat/reg_rf_boruta/anlyz_filtered/feat_summary.csv')

# aggregated results (each row unique for target)
df_agg = pd.read_csv('../out/20.0216 feat/reg_rf_boruta/anlyz_filtered/agg_summary_filtered.csv')

# %%
# Out:
#       target  score_rd  score_full  \
# 0      ACACA   0.34990     0.05240
# 1       ACLY   0.39931     0.07137
# 2       ACO2   0.39965     0.11507
# 3      ACSL3   0.11992     0.07110
# 4     ACTR1A   0.21392     0.03843
# ..       ...       ...         ...
# 521   YTHDF2   0.15939     0.09559
# 522     ZEB2   0.32135     0.20184
# 523  ZFP36L1   0.26758     0.13283
# 524   ZMYND8   0.29483     0.11850
# 525   ZNF217   0.27467     0.03568
#
#                                                feature  \
# 0    FASN (2194) [CERES],HSD17B12 (51144) [CERES],A...
# 1    FASN (2194) [CERES],ACSS1 (ENSG00000154930) [R...
# 2    ADSL (158) [CERES],IDH3A (3419) [CERES],SOD2 (...
# 3                    ACSL1 (ENSG00000151726) [RNA-seq]
# 4    ACTR1B (ENSG00000115073) [RNA-seq],VEZT (55591...
# ..                                                 ...
# 521                              CBLL1 (79872) [CERES]
# 522  ZEB2 (ENSG00000169554) [RNA-seq],LPAR4 (ENSG00...
# 523  PKN2 (5586) [CERES],CSF2 (ENSG00000164400) [RN...
# 524  MED23 (9439) [CERES],MED24 (9862) [CERES],CBFB...
# 525  ZNF217 (ENSG00000171940) [RNA-seq],RCOR1 (2318...
#
#                                              score_ind  \
# 0                                    0.366,0.001,0.039
# 1                                     0.242,0.14,0.118
# 2    0.172,0.078,0.15,0.153,0.194,0.016,0.018,0.116...
# 3                                                 0.09
# 4                               0.116,0.088,0.013,0.14
# ..                                                 ...
# 521                                               0.07
# 522                       0.246,0.23,0.022,0.103,0.148
# 523          0.045,0.179,0.053,0.089,0.009,0.039,0.115
# 524                            0.168,0.142,0.057,0.009
# 525                        0.063,0.1,0.064,0.022,0.181
#
#                                           feat_sources  \
# 0                          ['CERES', 'CERES', 'CERES']
# 1                        ['CERES', 'RNA-seq', 'CERES']
# 2    ['CERES', 'CERES', 'CERES', 'CERES', 'CERES', ...
# 3                                          ['RNA-seq']
# 4               ['RNA-seq', 'CERES', 'CERES', 'CERES']
# ..                                                 ...
# 521                                          ['CERES']
# 522  ['RNA-seq', 'RNA-seq', 'RNA-seq', 'RNA-seq', '...
# 523  ['CERES', 'RNA-seq', 'RNA-seq', 'CERES', 'RNA-...
# 524               ['CERES', 'CERES', 'CERES', 'CERES']
# 525  ['RNA-seq', 'CERES', 'RNA-seq', 'RNA-seq', 'CE...
#
#                                             feat_genes feat_gene1  \
# 0                         ['FASN', 'HSD17B12', 'ALG6']       FASN
# 1                           ['FASN', 'ACSS1', 'ACACA']       FASN
# 2    ['ADSL', 'IDH3A', 'SOD2', 'GMPS', 'TFRC', 'SDH...       ADSL
# 3                                            ['ACSL1']      ACSL1
# 4                   ['ACTR1B', 'VEZT', 'TUBB', 'RTCB']     ACTR1B
# ..                                                 ...        ...
# 521                                          ['CBLL1']      CBLL1
# 522   ['ZEB2', 'LPAR4', 'GYPC', 'ARHGEF6', 'PPP1R13L']       ZEB2
# 523  ['PKN2', 'CSF2', 'IL31RA', 'PTPN1', 'EPHA2', '...       PKN2
# 524                ['MED23', 'MED24', 'CBFB', 'RUNX1']      MED23
# 525  ['ZNF217', 'RCOR1', 'AL157838.1', 'MEIS2', 'KD...     ZNF217
#
#     feat_source1 feat_gene2  ... feat_source6 feat_gene7 feat_source7  \
# 0          CERES   HSD17B12  ...          NaN        NaN          NaN
# 1          CERES      ACSS1  ...          NaN        NaN          NaN
# 2          CERES      IDH3A  ...        CERES     ADAM12      RNA-seq
# 3        RNA-seq        NaN  ...          NaN        NaN          NaN
# 4        RNA-seq       VEZT  ...          NaN        NaN          NaN
# ..           ...        ...  ...          ...        ...          ...
# 521        CERES        NaN  ...          NaN        NaN          NaN
# 522      RNA-seq      LPAR4  ...          NaN        NaN          NaN
# 523        CERES       CSF2  ...      RNA-seq     AHNAK2      RNA-seq
# 524        CERES      MED24  ...          NaN        NaN          NaN
# 525      RNA-seq      RCOR1  ...          NaN        NaN          NaN
#
#     feat_gene8 feat_source8 feat_gene9 feat_source9 feat_gene10 feat_source10  \
# 0          NaN          NaN        NaN          NaN         NaN           NaN
# 1          NaN          NaN        NaN          NaN         NaN           NaN
# 2         ATIC        CERES      PLOD2      RNA-seq         NaN           NaN
# 3          NaN          NaN        NaN          NaN         NaN           NaN
# 4          NaN          NaN        NaN          NaN         NaN           NaN
# ..         ...          ...        ...          ...         ...           ...
# 521        NaN          NaN        NaN          NaN         NaN           NaN
# 522        NaN          NaN        NaN          NaN         NaN           NaN
# 523        NaN          NaN        NaN          NaN         NaN           NaN
# 524        NaN          NaN        NaN          NaN         NaN           NaN
# 525        NaN          NaN        NaN          NaN         NaN           NaN
#
#     feats_n
# 0         3
# 1         3
# 2         9
# 3         1
# 4         4
# ..      ...
# 521       1
# 522       5
# 523       7
# 524       4
# 525       5
#
# [526 rows x 28 columns]
